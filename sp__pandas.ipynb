# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhivya-kuppusamy/superpacc-bytes/blob/main/sp__pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# What is Pandas-software library data manipulation&analysis.large set of data can be preprocessed different b/w dataframe and database-functionality and operation sql-fast than pandas
# quantitative-level like Manager,HR-numerical data-qualtiative-non numerical polar-big data.
# Functionality are more than sql
# POLARS-similar to pandas,which are mainl used for big data

# %% [markdown]
# series and dataframe difference
# series is id
# dataframe is 2d

# %%
import pandas as pd
import numpy as np

# %%
a=np.array([10,12,13,44,56])
a
# Out:
# array([10, 12, 13, 44, 56])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a[1]
# Out:
# 12

# %%
s=pd.Series([10,12,13,44,56])
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    10
# 1    12
# 2    13
# 3    44
# 4    56
# dtype: int64

# %%
s[3]
# Out:
# 44

# %%
s.drop(3,inplace=True)

# %%
s.iloc[3]
# Out:
# 56

# %%
s.loc[4]
# Out:
# 56

# %%
s.index
# Out:
# Int64Index([0, 1, 2, 4], dtype='int64')

# %%
import pandas as pd
ss=pd.Series([10,20,30,40],index=['a','b','c','d'])
ss
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
ss=pd.Series([10,20,30,40],index=['a','a','c','d'])
ss
# Out:
# a    10
# a    20
# c    30
# d    40
# dtype: int64

# %%
ss.iloc[1]
# Out:
# 20

# %%
ss.loc['a']
# Out:
# a    10
# a    20
# dtype: int64

# %%
data=[['dhivi',20,'05-05-2004'],['vino',None,None],['clarke',None,'06-05-2004']]
print(data)
print(type(data))
# Out:
# [['dhivi', 20, '05-05-2004'], ['vino', None, None], ['clarke', None, '06-05-2004']]
# <class 'list'>

# %%
df=pd.DataFrame(data)
df
# Out:
#         0     1           2
# 0   dhivi  20.0  05-05-2004
# 1    vino   NaN        None
# 2  clarke   NaN  06-05-2004

# %%
df[0:3]
# Out:
#         0     1           2
# 0   dhivi  20.0  05-05-2004
# 1    vino   NaN        None
# 2  clarke   NaN  06-05-2004

# %%
#if i want to access dhivi alone
df[0][0]
# Out:
# 'dhivi'

# %%
df[[0,2]]
# Out:
#         0           2
# 0   dhivi  05-05-2004
# 1    vino        None
# 2  clarke  06-05-2004

# %%
#if i want to access vino column
df[1:2]
# Out:
#       0   1     2
# 1  vino NaN  None

# %%
df=pd.DataFrame(data,columns=['name','Age','DOB'])
df
# Out:
#      name   Age         DOB
# 0   dhivi  20.0  05-05-2004
# 1    vino   NaN        None
# 2  clarke   NaN  06-05-2004

# %%
df['name']
# Out:
# 0     dhivi
# 1      vino
# 2    clarke
# Name: name, dtype: object

# %%
df['Age']
# Out:
# 0    20.0
# 1     NaN
# 2     NaN
# Name: Age, dtype: float64

# %%
df['name'][0]
# Out:
# 'dhivi'

# %%
#another different methods to acess the o th index
df.loc[0,'name']
# Out:
# 'dhivi'

# %%
df.iloc[0][0]
# Out:
# 'dhivi'

# %%
 df[0:1]
# Out:
#     name   Age         DOB
# 0  dhivi  20.0  05-05-2004

# %%
s=pd.Series([1,2,3])
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s.plot.bar()
# Out:
# <Axes: >

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s=s.to_numpy()

# %%
type(s)
# Out:
# numpy.ndarray

# %%
df.tail(-2)
# Out:
#      name  Age         DOB
# 2  clarke  NaN  06-05-2004

# %%
df.head(1)
# Out:
#     name   Age         DOB
# 0  dhivi  20.0  05-05-2004

# %%
df
# Out:
#      name   Age         DOB
# 0   dhivi  20.0  05-05-2004
# 1    vino   NaN        None
# 2  clarke   NaN  06-05-2004

# %%
import pandas as pd
import numpy as np

data = {
    'Name': ['Alice', 'Bob', 'Cathy', None, 'Eva', None, 'Grace', 'Hannah', None, 'Jack'],
    'Age': [25, None, 22, None, 28, None, None, None, 32, 27],
    'DOB': ['1998-04-15', None, '1999-12-05', None, '1993-02-18', None, None, '1994-05-14', None, '1996-10-03']
}

df = pd.DataFrame(data)
print(df)
# Out:
#      Name   Age         DOB
# 0   Alice  25.0  1998-04-15
# 1     Bob   NaN        None
# 2   Cathy  22.0  1999-12-05
# 3    None   NaN        None
# 4     Eva  28.0  1993-02-18
# 5    None   NaN        None
# 6   Grace   NaN        None
# 7  Hannah   NaN  1994-05-14
# 8    None  32.0        None
# 9    Jack  27.0  1996-10-03

# %%
df.isnull().sum()
# Out:
# Name    3
# Age     5
# DOB     5
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Name    7
# Age     5
# DOB     5
# dtype: int64

# %%
df.dropna() #drop all the values which hava Nan
# Out:
#     Name   Age         DOB
# 0  Alice  25.0  1998-04-15
# 2  Cathy  22.0  1999-12-05
# 4    Eva  28.0  1993-02-18
# 9   Jack  27.0  1996-10-03

# %%
df
# Out:
#      Name   Age         DOB
# 0   Alice  25.0  1998-04-15
# 1     Bob   NaN        None
# 2   Cathy  22.0  1999-12-05
# 3    None   NaN        None
# 4     Eva  28.0  1993-02-18
# 5    None   NaN        None
# 6   Grace   NaN        None
# 7  Hannah   NaN  1994-05-14
# 8    None  32.0        None
# 9    Jack  27.0  1996-10-03

# %%
df.drop(['Age'],axis=1,inplace=True)

# %%
df
# Out:
#      Name         DOB
# 0   Alice  1998-04-15
# 1     Bob        None
# 2   Cathy  1999-12-05
# 3    None        None
# 4     Eva  1993-02-18
# 5    None        None
# 6   Grace        None
# 7  Hannah  1994-05-14
# 8    None        None
# 9    Jack  1996-10-03

# %%
df.drop([0,2])
# Out:
#      Name         DOB
# 1     Bob        None
# 3    None        None
# 4     Eva  1993-02-18
# 5    None        None
# 6   Grace        None
# 7  Hannah  1994-05-14
# 8    None        None
# 9    Jack  1996-10-03

# %%
a
# Out:
# array([10, 12, 13, 44, 56])

# %%
a[a>40]#provide the values that are greater than 3
# Out:
# array([44, 56])

# %%
a>40#provide true or false
# Out:
# array([False, False, False,  True,  True])

# %%
a[a%2!=0] #odd numbers
# Out:
# array([13])

# %%
a[a%2==0]#even numbers
# Out:
# array([10, 12, 44, 56])

# %%
df
# Out:
#      Name         DOB
# 0   Alice  1998-04-15
# 1     Bob        None
# 2   Cathy  1999-12-05
# 3    None        None
# 4     Eva  1993-02-18
# 5    None        None
# 6   Grace        None
# 7  Hannah  1994-05-14
# 8    None        None
# 9    Jack  1996-10-03

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   DOB     5 non-null      object
# dtypes: object(2)
# memory usage: 288.0+ bytes

# %%
df['Name'].str.contains('e')
# Out:
# 0     True
# 1    False
# 2    False
# 3     None
# 4    False
# 5     None
# 6     True
# 7    False
# 8     None
# 9    False
# Name: Name, dtype: object

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)
# Out:
# (10, 2)
# 20
# [RangeIndex(start=0, stop=10, step=1), Index(['Name', 'DOB'], dtype='object')]
# 2
# Name    object
# DOB     object
# dtype: object
# RangeIndex(start=0, stop=10, step=1)
# Index(['Name', 'DOB'], dtype='object')
# [['Alice' '1998-04-15']
#  ['Bob' None]
#  ['Cathy' '1999-12-05']
#  [None None]
#  ['Eva' '1993-02-18']
#  [None None]
#  ['Grace' None]
#  ['Hannah' '1994-05-14']
#  [None None]
#  ['Jack' '1996-10-03']]

# %%
df.head()
# Out:
#     Name         DOB
# 0  Alice  1998-04-15
# 1    Bob        None
# 2  Cathy  1999-12-05
# 3   None        None
# 4    Eva  1993-02-18

# %%
df.tail()
# Out:
#      Name         DOB
# 5    None        None
# 6   Grace        None
# 7  Hannah  1994-05-14
# 8    None        None
# 9    Jack  1996-10-03

# %%
df2=pd.concat([df,df])
df2
# Out:
#      Name         DOB
# 0   Alice  1998-04-15
# 1     Bob        None
# 2   Cathy  1999-12-05
# 3    None        None
# 4     Eva  1993-02-18
# 5    None        None
# 6   Grace        None
# 7  Hannah  1994-05-14
# 8    None        None
# 9    Jack  1996-10-03
# 0   Alice  1998-04-15
# 1     Bob        None
# 2   Cathy  1999-12-05
# 3    None        None
# 4     Eva  1993-02-18
# 5    None        None
# 6   Grace        None
# 7  Hannah  1994-05-14
# 8    None        None
# 9    Jack  1996-10-03

# %%
df['Name']
# Out:
# 0     Alice
# 1       Bob
# 2     Cathy
# 3      None
# 4       Eva
# 5      None
# 6     Grace
# 7    Hannah
# 8      None
# 9      Jack
# Name: Name, dtype: object

# %%
df.DOB
# Out:
# 0    1998-04-15
# 1          None
# 2    1999-12-05
# 3          None
# 4    1993-02-18
# 5          None
# 6          None
# 7    1994-05-14
# 8          None
# 9    1996-10-03
# Name: DOB, dtype: object

# %%
df['DOB'][0]
# Out:
# '1998-04-15'

# %%
df[['Name','DOB']]
# Out:
#      Name         DOB
# 0   Alice  1998-04-15
# 1     Bob        None
# 2   Cathy  1999-12-05
# 3    None        None
# 4     Eva  1993-02-18
# 5    None        None
# 6   Grace        None
# 7  Hannah  1994-05-14
# 8    None        None
# 9    Jack  1996-10-03

# %%
df.loc[0][0]
# Out:
# 'Alice'

# %%
df.loc[0,'Name']
# Out:
# 'Alice'

# %%
df.iloc[0,0]
# Out:
# 'Alice'

# %%
df.iloc[0,1]
# Out:
# '1998-04-15'

# %%
df["DOB"][1]='30-03-2004'

# %%
df
# Out:
#      Name         DOB
# 0   Alice  1998-04-15
# 1     Bob  30-03-2004
# 2   Cathy  1999-12-05
# 3    None        None
# 4     Eva  1993-02-18
# 5    None        None
# 6   Grace        None
# 7  Hannah  1994-05-14
# 8    None        None
# 9    Jack  1996-10-03

# %%
df.iloc[1][1]
# Out:
# '30-03-2004'

# %% [markdown]
# READING DATA FROM FILE
# 1.CSV 2.JSON 3.EXCEL 4.SQL QUERIES 5.HTML 6.TSV

# %%
df1=pd.read_html("https://en.wikipedia.org/wiki/List_of_highest-grossing_films")
df=pd.DataFrame(df1)
print(df1)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py:568: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])
# [    Rank  Peak                                          Title  \
# 0      1     1                                         Avatar
# 1      2     1                              Avengers: Endgame
# 2      3     3                       Avatar: The Way of Water
# 3      4     1                                        Titanic
# 4      5     3                   Star Wars: The Force Awakens
# 5      6     4                         Avengers: Infinity War
# 6      7     6                        Spider-Man: No Way Home
# 7      8     3                                 Jurassic World
# ...

# %%
df.head(10)
# Out:
#                                                    0
# 0      Rank  Peak                                ...
# 1     Rank                         Title Worldwid...
# 2       Year                      Title  \
# 0    1...
# 3       Established                       Title  ...
# 4                                                ...
# 5  Empty DataFrame
# Columns: [Rank, Series, Total ...
# 6                                                ...
# 7                                                ...
# 8         0                                      ...
# 9       0                                        ...

# %%
df2=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df2
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       89 non-null     object
# dtypes: object(1)
# memory usage: 840.0+ bytes

# %%
df2.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df2.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.item_price=df2.item_price.str.replace('$', '')
df2.head(10)
# Out:
# <ipython-input-271-e0a67f51d926>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2.item_price=df2.item_price.str.replace('$', '')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
# ...

# %%
df2.item_price=df2.item_price.astype(float)
df2
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
type(df2.item_price[0])
# Out:
# numpy.float64

# %%
#df2.item_price=df2.item_price*100

# %%
#df2.item_price

# %%
df2.item_name.unique
# Out:
# <bound method Series.unique of 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object>

# %%
df_drink=df2[df2.item_price<1.1]
df_drink
# Out:
#       order_id  quantity      item_name choice_description  item_price
# 28          14         1    Canned Soda       [Dr. Pepper]        1.09
# 34          17         1  Bottled Water                NaN        1.09
# 53          24         1    Canned Soda           [Sprite]        1.09
# 87          38         1  Bottled Water                NaN        1.09
# 107         47         1    Canned Soda       [Dr. Pepper]        1.09
# ...        ...       ...            ...                ...         ...
# 3936      1578         1    Canned Soda  [Diet Dr. Pepper]        1.09
# 4001      1602         1  Bottled Water                NaN        1.09
# 4008      1604         1    Canned Soda        [Diet Coke]        1.09
# 4051      1621         1    Canned Soda           [Sprite]        1.09
# 4069      1629         1  Bottled Water                NaN        1.09
#
# [106 rows x 5 columns]

# %%
print(df_drink.item_name.unique())#display the unique items in that column
print(df_drink.item_name.nunique())#display the total number of the unique items in that column
# Out:
# ['Canned Soda' 'Bottled Water']
# 2

# %%
df_drink.item_name.value_counts()#display all the items present with this count
# Out:
# Canned Soda      84
# Bottled Water    22
# Name: item_name, dtype: int64

# %%
df2[df2.item_name=='Steak Burrito']
# Out:
#       order_id  quantity      item_name  \
# 7            4         1  Steak Burrito
# 9            5         1  Steak Burrito
# 31          16         1  Steak Burrito
# 43          20         1  Steak Burrito
# 46          21         1  Steak Burrito
# ...        ...       ...            ...
# 4546      1807         1  Steak Burrito
# 4607      1829         1  Steak Burrito
# 4610      1830         1  Steak Burrito
# 4617      1833         1  Steak Burrito
# 4618      1833         1  Steak Burrito
#
#                                      choice_description  item_price
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        9.25
# 31    [[Roasted Chili Corn Salsa (Medium), Fresh Tom...        8.99
# 43    [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...       11.75
# 46    [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...        8.99
# ...                                                 ...         ...
# ...

# %%
df2[df2.item_name=='Steak Burrito'].choice_description.value_counts()
# Out:
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                        12
# [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]                                     6
# [Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]                                        6
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]     5
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                            5
#                                                                                                                             ..
# [Fresh Tomato Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]                                    1
# ...

# %%
df2[df2.item_name=='Steak Burrito'].choice_description.nunique()
# Out:
# 251

# %%
df2.dropna(inplace=True)

# %%
df2.choice_description
# Out:
# 0                                                     NaN
# 1                                            [Clementine]
# 2                                                 [Apple]
# 3                                                     NaN
# 4       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#                               ...
# 4617    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4620    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4621    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# Name: choice_description, Length: 4622, dtype: object

# %%
df2[df2.choice_description.str.contains('Black Beans')].item_name.value_counts()#this dont work if null value contains
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df2[(df2.item_price<10)&(df2.item_name=='Chicken Bowl')].sort_values(["item_price"])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
df3=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
df4=pd.DataFrame(df3)
df4
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df4[(df4.star_rating>8)&(df4.content_rating== 'PG-13')].sort_values(['duration'])
# Out:
#      star_rating                                              title  \
# 175          8.2                                      Touch of Evil
# 232          8.1                                  Chungking Express
# 279          8.1                    The Perks of Being a Wallflower
# 191          8.2                                    The Sixth Sense
# 286          8.1                  The Diving Bell and the Butterfly
# 209          8.1                                 The Imitation Game
# 240          8.1                               The Bourne Ultimatum
# 25           8.6                                  Life Is Beautiful
# 196          8.1                            Guardians of the Galaxy
# 180          8.2                                       Hotel Rwanda
# 73           8.4                            Jodaeiye Nader az Simin
# 260          8.1                                     The Sea Inside
# 118          8.3                 Indiana Jones and the Last Crusade
# ...

# %%
df4[df4.actors_list.str.contains('Leonardo DiCaprio')].sort_values(["duration","star_rating"])
# Out:
#      star_rating                        title content_rating      genre  \
# 562          7.8  What's Eating Gilbert Grape          PG-13      Drama
# 244          8.1               Shutter Island              R    Mystery
# 340          8.0          Catch Me If You Can          PG-13  Biography
# 309          8.0                Blood Diamond              R  Adventure
# 11           8.8                    Inception          PG-13     Action
# 49           8.5                 The Departed              R      Crime
# 59           8.5             Django Unchained              R    Western
# 828          7.5            Gangs of New York              R      Crime
# 888          7.5                  The Aviator          PG-13  Biography
# 143          8.2      The Wolf of Wall Street              R  Biography
# 620          7.7                      Titanic          PG-13      Drama
#
#      duration                                        actors_list
# ...

# %%
df4[df4.actors_list.str.contains("u'Johnny Depp'")].sort_values(['duration','star_rating'],ascending=(False,True))
# Out:
#      star_rating                                              title  \
# 271          8.1  Pirates of the Caribbean: The Curse of the Bla...
# 560          7.8                                      Donnie Brasco
# 418          7.9                                            Ed Wood
# 725          7.6                                               Blow
# 594          7.7                                           Dead Man
# 608          7.7                     Fear and Loathing in Las Vegas
# 562          7.8                        What's Eating Gilbert Grape
# 904          7.5     Sweeney Todd: The Demon Barber of Fleet Street
# 547          7.8                                  Finding Neverland
# 951          7.4                                      Sleepy Hollow
# 379          8.0                                Edward Scissorhands
# 869          7.5                          A Nightmare on Elm Street
#
#     content_rating      genre  duration  \
# ...

# %%
df5=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
df5
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
df5.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df5.dropna(how='all')
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
df5.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
df5.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
df5['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
df5['Shape Reported'].isnull().sum()
# Out:
# 2644

# %%
df6=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
df6
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
df6.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
print(df6.beer_servings.min())
print(df6.beer_servings.max())
# Out:
# 0
# 376

# %%
df6[df6.continent=='Asia'].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
df6.groupby('continent').beer_servings.agg(['mean','min','max'])
# Out:
#                      mean  min  max
# continent
# Africa          61.471698    0  376
# Asia            37.045455    0  247
# Europe         193.777778    0  361
# North America  145.434783    1  285
# Oceania         89.687500    0  306
# South America  175.083333   93  333
